# %%
import sys
sys.path.append("..")

# %%
from datasets.company import operacoes_financeiras
df_fin = operacoes_financeiras()
# Out:
# 2026-02-19 10:52:03.972 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-19 10:52:03.986 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-19 10:52:03.986 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-19 10:52:03,986 | INFO | datasets | Solicitado dataset company.operacoes_financeiras
# 2026-02-19 10:52:03,986 | INFO | datasets | Iniciando carga | sistema=Company | tabela=Company_tb_Operacoes_Financeiras | path=C:\Users\Israel Panazollo\Documents\AnalisesPy\plataforma_bi\data\staging\Company\Company_tb_Operacoes_Financeiras.csv
# 2026-02-19 10:52:04,520 | INFO | datasets | Carga concluída | sistema=Company | tabela=Company_tb_Operacoes_Financeiras | linhas=67707 | colunas=34 | tempo=0.534s

# %%
df_fin.head()
# Out:
#    Cod_produto Desc_produto  Cod_cliente            Nome_cliente  Cod_unidade  \
# 0            0          NaN          482  Municipio de Carazinho          673
# 1            0          NaN          421      SANDRO DA SILVEIRA          673
# 2            0          NaN          421      SANDRO DA SILVEIRA          673
# 3            0          NaN          421      SANDRO DA SILVEIRA          673
# 4            0          NaN          421      SANDRO DA SILVEIRA          673
#
#   Estado_cliente Num_Doc_Fiscal Emitido_em  Qtd_itens  Valor_total  ...  \
# 0             RS      1575-2023 2023-06-02        0.0     -2903.08  ...
# 1             RS       00011695 2023-06-07        0.0      -136.21  ...
# 2             RS       00011695 2023-06-07        0.0      -136.21  ...
# 3             RS       00011695 2023-06-07        0.0      -136.21  ...
# 4             RS       00011695 2023-06-07        0.0      -136.21  ...
#
# ...

# %%
df_fin["Emitido_em"].isna().sum()
# Out:
# np.int64(2)

# %%
df_fin["Emitido_em"].head()
# Out:
# 0   2023-06-02
# 1   2023-06-07
# 2   2023-06-07
# 3   2023-06-07
# 4   2023-06-07
# Name: Emitido_em, dtype: datetime64[ns]

# %%
import pandas as pd
caminho = "../data/staging/Company/Company_tb_Operacoes_Financeiras.csv"
df = pd.read_csv(caminho)

# %%
df["Emitido_em"].isna().sum()
# Out:
# np.int64(2)

# %%
df["Emitido_em"].head()
# Out:
# 0    2023-06-02 00:00:00
# 1    2023-06-07 00:00:00
# 2    2023-06-07 00:00:00
# 3    2023-06-07 00:00:00
# 4    2023-06-07 00:00:00
# Name: Emitido_em, dtype: object
